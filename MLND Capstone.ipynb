# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
TEST = "./raw_data/test.csv"
TRAIN = "./raw_data/train.csv"

# %%
train = pd.read_csv(TRAIN)

# %%
plt.xticks(np.arange(10), np.arange(10))
plt.xlabel('Class')
train.label.plot(kind='hist', bins=np.arange(-0.5, 10.5, 1))

# %%
import csv
FILE = "./models/attempt_3/score_6.csv"

# %%
f = open(FILE, 'r')
next(f)
reader = csv.reader(f)

# %%
data = [tuple([float(x) for x in line]) for line in reader]

# %%
plt.xlabel('epoch')
plt.ylabel('cost')
plt.title('Cost Over Time')
plt.plot([x[2] for x in data])
